# %%
import numpy as np # math arrays manipulation
import pandas as pd # for data management
import os 
from matplotlib import pyplot as plt # for plot

# %%
path = os.getcwd() + "/Rogue_242.csv" # make sure you are in the correct directory
rogue = pd.read_csv(path)

# %%
rogue.info()
rogue.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MonthNumeric  162 non-null    int64
#  1   MonthFactor   162 non-null    object
#  2   Year          162 non-null    int64
#  3   RogueSales    162 non-null    int64
#  4   Unemployment  162 non-null    float64
#  5   RogueQueries  162 non-null    int64
#  6   CPIAll        162 non-null    float64
#  7   CPIEnergy     162 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 10.2+ KB
#    MonthNumeric MonthFactor  Year  RogueSales  Unemployment  RogueQueries  \
# 0             1     January  2008        5435           5.0            18
# 1             2    February  2008        5223           4.9            11
# 2             3       March  2008        6873           5.1            18
# 3             4       April  2008        5814           5.0            17
# 4             5         May  2008        7467           5.4            17
#
#     CPIAll  CPIEnergy
# 0  212.174    226.775
# 1  212.687    229.731
# 2  213.448    233.349
# 3  213.942    234.778
# 4  215.208    243.924

# %%
rogue['MonthFactor'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'Septeber', 'October', 'November', 'Decemeber'],
#       dtype=object)

# %%
dummy = pd.get_dummies(rogue['MonthFactor'], drop_first=True)
rogue_encoded = pd.concat([rogue, dummy], axis=1).drop('MonthFactor', axis=1)

# %%
rogue_encoded.head()
# Out:
#    MonthNumeric  Year  RogueSales  Unemployment  RogueQueries   CPIAll  \
# 0             1  2008        5435           5.0            18  212.174
# 1             2  2008        5223           4.9            11  212.687
# 2             3  2008        6873           5.1            18  213.448
# 3             4  2008        5814           5.0            17  213.942
# 4             5  2008        7467           5.4            17  215.208
#
#    CPIEnergy  August  Decemeber  February  January  July  June  March  May  \
# 0    226.775       0          0         0        1     0     0      0    0
# 1    229.731       0          0         1        0     0     0      0    0
# 2    233.349       0          0         0        0     0     0      1    0
# 3    234.778       0          0         0        0     0     0      0    0
# 4    243.924       0          0         0        0     0     0      0    1
#
#    November  October  Septeber
# 0         0        0         0
# 1         0        0         0
# 2         0        0         0
# 3         0        0         0
# 4         0        0         0

# %%
import statsmodels.api as sm

rogue_train = rogue_encoded.sample(frac=0.8, random_state=1)
rogue_test = rogue_encoded.drop(rogue_train.index)

# Choose the features to be used
cols = rogue_encoded.columns.drop('RogueSales')
X_train = rogue_train[cols]
y_train = rogue_train['RogueSales']

# We must add an intercept as the standard model doesn't automatically fit one
X_train = sm.add_constant(X_train)

# fit the data to the model
model = sm.OLS(y_train, X_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             RogueSales   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     42.03
# Date:                Sun, 02 Oct 2022   Prob (F-statistic):           5.37e-40
# Time:                        22:11:32   Log-Likelihood:                -1261.7
# No. Observations:                 130   AIC:                             2557.
# Df Residuals:                     113   BIC:                             2606.
# Df Model:                          16
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.399e+07   2.18e+06     -6.407      0.000   -1.83e+07   -9.66e+06
# MonthNumeric -2.546e+05   3.98e+04     -6.397      0.000   -3.33e+05   -1.76e+05
# Year          7656.5576   1196.873      6.397      0.000    5285.337       1e+04
# Unemployment -1523.4585    244.798     -6.223      0.000   -2008.447   -1038.470
# RogueQueries   202.0501     72.618      2.782      0.006      58.180     345.920
# CPIAll       -1806.6805    338.857     -5.332      0.000   -2478.017   -1135.344
# CPIEnergy      126.3576     34.947      3.616      0.000      57.122     195.594
# August        1.024e+06   1.59e+05      6.425      0.000    7.08e+05    1.34e+06
# Decemeber     2.046e+06   3.19e+05      6.411      0.000    1.41e+06    2.68e+06
# February     -5.074e+05   7.99e+04     -6.350      0.000   -6.66e+05   -3.49e+05
# January       -7.65e+05    1.2e+05     -6.390      0.000      -1e+06   -5.28e+05
# July          7.667e+05    1.2e+05      6.415      0.000     5.3e+05       1e+06
# June           5.13e+05   7.98e+04      6.429      0.000    3.55e+05    6.71e+05
# March        -2.499e+05      4e+04     -6.241      0.000   -3.29e+05   -1.71e+05
# May           2.588e+05   3.99e+04      6.488      0.000     1.8e+05    3.38e+05
# November      1.787e+06   2.79e+05      6.401      0.000    1.23e+06    2.34e+06
# October       1.532e+06   2.39e+05      6.400      0.000    1.06e+06    2.01e+06
# Septeber      1.279e+06   1.99e+05      6.415      0.000    8.84e+05    1.67e+06
# ==============================================================================
# Omnibus:                       15.538   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.009
# Skew:                           0.682   Prob(JB):                     4.52e-05
# Kurtosis:                       4.354   Cond. No.                     1.88e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.54e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
coef_df = pd.DataFrame(model.summary().tables[1].data)
coef_df.columns = coef_df.iloc[0]
coef_df.index = coef_df[""]
coef_df = coef_df.iloc[1:,1:]
coef_df
# Out:
# 0                   coef    std err          t   P>|t|     [0.025     0.975]
#
# const         -1.399e+07   2.18e+06     -6.407   0.000  -1.83e+07  -9.66e+06
# MonthNumeric  -2.546e+05   3.98e+04     -6.397   0.000  -3.33e+05  -1.76e+05
# Year           7656.5576   1196.873      6.397   0.000   5285.337      1e+04
# Unemployment  -1523.4585    244.798     -6.223   0.000  -2008.447  -1038.470
# RogueQueries    202.0501     72.618      2.782   0.006     58.180    345.920
# CPIAll        -1806.6805    338.857     -5.332   0.000  -2478.017  -1135.344
# CPIEnergy       126.3576     34.947      3.616   0.000     57.122    195.594
# August         1.024e+06   1.59e+05      6.425   0.000   7.08e+05   1.34e+06
# Decemeber      2.046e+06   3.19e+05      6.411   0.000   1.41e+06   2.68e+06
# February      -5.074e+05   7.99e+04     -6.350   0.000  -6.66e+05  -3.49e+05
# January        -7.65e+05    1.2e+05     -6.390   0.000     -1e+06  -5.28e+05
# July           7.667e+05    1.2e+05      6.415   0.000    5.3e+05      1e+06
# June            5.13e+05   7.98e+04      6.429   0.000   3.55e+05   6.71e+05
# March         -2.499e+05      4e+04     -6.241   0.000  -3.29e+05  -1.71e+05
# May            2.588e+05   3.99e+04      6.488   0.000    1.8e+05   3.38e+05
# November       1.787e+06   2.79e+05      6.401   0.000   1.23e+06   2.34e+06
# October        1.532e+06   2.39e+05      6.400   0.000   1.06e+06   2.01e+06
# Septeber       1.279e+06   1.99e+05      6.415   0.000   8.84e+05   1.67e+06

# %%
y_test = rogue_test['RogueSales']
X_test = rogue_test[cols]

X_test = sm.add_constant(X_test)

pred = model.predict(X_test)

# %%
RSS = 0
TSS = 0

y_values = y_test.values
pred_values = pred.values

def mean(L) :
    mean = 0
    n = len(L)
    for i in range(n) :
        mean += L[i]
    return mean/n

m_bar = mean(y_values)
m = len(pred_values)
for i in range(m) :
    d = pred_values[i] - y_values[i]
    t = pred_values[i] - m_bar
    RSS += d*d
    TSS += t*t

print('OSR is {}'.format(1-RSS/TSS*(m-1)/(m-len(cols)-1)))
# Out:
# OSR is 0.6040900300737349

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = [variance_inflation_factor(X_train.values, i) for i in range(1, X_train.shape[1])] 
vif
# Out:
# c:\Users\minon\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# [inf,
#  152.92456280194384,
#  2.149760490544606,
#  25.23648034074959,
#  187.10095757226904,
#  4.497812729527373,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf]

# %%
#After computing VIF I droped Year
cols_adjusted = cols.drop('MonthNumeric')

# %%
cols_adjusted_2 = cols_adjusted.drop('Year')

# %%
X_train = rogue_train[cols_adjusted_2]
X_train = sm.add_constant(X_train)
vif = [variance_inflation_factor(X_train.values, i) for i in range(1, X_train.shape[1])]
vif
# Out:
# [1.9885657223787512,
#  23.687256010779503,
#  18.781268300733856,
#  1.5208798815279958,
#  1.605535164255354,
#  1.761247945188605,
#  1.6081244337029712,
#  1.6653856758687586,
#  1.9267117664608824,
#  1.8032789635381177,
#  1.617558053644134,
#  1.864605665325457,
#  1.709612060500973,
#  1.6475760547879386,
#  1.5266262008226623]

# %%
# Let's try with this training set :

model = sm.OLS(y_train, X_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             RogueSales   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     31.18
# Date:                Sun, 02 Oct 2022   Prob (F-statistic):           2.35e-33
# Time:                        22:11:42   Log-Likelihood:                -1281.7
# No. Observations:                 130   AIC:                             2595.
# Df Residuals:                     114   BIC:                             2641.
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -2.113e+04   2.33e+04     -0.907      0.366   -6.73e+04     2.5e+04
# Unemployment -1952.2770    273.579     -7.136      0.000   -2494.234   -1410.320
# RogueQueries    86.9502     81.750      1.064      0.290     -74.997     248.897
# CPIAll         249.3570    124.750      1.999      0.048       2.228     496.486
# CPIEnergy      -55.5190     23.613     -2.351      0.020    -102.296      -8.741
# August        4535.9666   2165.252      2.095      0.038     246.618    8825.315
# Decemeber     4305.9971   1988.800      2.165      0.032     366.199    8245.795
# February      3617.7422   2166.998      1.669      0.098    -675.063    7910.548
# January        786.2615   2100.774      0.374      0.709   -3375.356    4947.879
# July          2184.6620   2007.041      1.088      0.279   -1791.271    6160.595
# June          2602.8800   2012.391      1.293      0.198   -1383.651    6589.411
# March         5959.0950   2173.344      2.742      0.007    1653.717    1.03e+04
# May           3802.7648   1910.790      1.990      0.049      17.504    7588.026
# November       907.0504   2037.941      0.445      0.657   -3130.094    4944.195
# October        554.2421   2089.511      0.265      0.791   -3585.063    4693.547
# Septeber      3516.3050   2230.252      1.577      0.118    -901.808    7934.418
# ==============================================================================
# Omnibus:                        3.079   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.749
# Skew:                           0.198   Prob(JB):                        0.253
# Kurtosis:                       3.592   Cond. No.                     1.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_test = rogue_test['RogueSales']
X_test = rogue_test[cols_adjusted_2]

X_test = sm.add_constant(X_test)

pred = model.predict(X_test)


RSS = 0
TSS = 0

y_values = y_test.values
pred_values = pred.values

def mean(L) :
    mean = 0
    n = len(L)
    for i in range(n) :
        mean += L[i]
    return mean/n

m_bar = mean(y_values)
m = len(pred_values)
for i in range(m) :
    d = pred_values[i] - y_values[i]
    t = pred_values[i] - m_bar
    RSS += d*d
    TSS += t*t

print('OSR is {}'.format(1-RSS/TSS))
# Out:
# OSR is 0.727047020042509

# %%
rogue_train['CPIA/CPIE'] = rogue_train['CPIAll']-rogue_train['CPIEnergy']

# %%
cols = rogue_train.columns
new_cols = cols.drop(['CPIA/CPIE','Decemeber','March','MonthNumeric','January','February','May','June','July','August','Septeber','November','October','CPIAll','Unemployment','RogueSales'])

# %%
X_train = rogue_train[new_cols]
vif = [variance_inflation_factor(X_train.values, i) for i in range(1, X_train.shape[1])] 
vif
# Out:
# [4.317954428179216, 100.39309647586295]

# %%
model = sm.OLS(y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             RogueSales   R-squared (uncentered):                   0.925
# Model:                            OLS   Adj. R-squared (uncentered):              0.924
# Method:                 Least Squares   F-statistic:                              524.6
# Date:                Sun, 02 Oct 2022   Prob (F-statistic):                    2.44e-71
# Time:                        23:41:05   Log-Likelihood:                         -1313.7
# No. Observations:                 130   AIC:                                      2633.
# Df Residuals:                     127   BIC:                                      2642.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Year             3.5243      2.781      1.267      0.207      -1.978       9.026
# RogueQueries   330.3519     21.270     15.531      0.000     288.262     372.442
# CPIEnergy      -12.7638     24.048     -0.531      0.597     -60.351      34.824
# ==============================================================================
# Omnibus:                        4.919   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                4.704
# Skew:                           0.320   Prob(JB):                       0.0952
# Kurtosis:                       3.677   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_test = rogue_test['RogueSales']
X_test = rogue_test[new_cols]
pred = model.predict(X_test)


RSS = 0
TSS = 0

y_values = y_test.values
pred_values = pred.values

m_bar = mean(y_values)
m = len(pred_values)
for i in range(m) :
    d = pred_values[i] - y_values[i]
    t = pred_values[i] - m_bar
    RSS += d*d
    TSS += t*t

print('OSR is {}'.format(1-RSS/TSS))
# Out:
# OSR is 0.6789134637663196

# %%
col = rogue.columns
rogue_normed = rogue
for i in range(len(col)) :
    rogue_normed[col] = (rogue[col]-rogue[col].mean())/np.sqrt(rogue[col].var())
rogue_normed.cov()
# Out:
#               MonthNumeric  MonthFactor  RogueSales  Unemployment  \
# MonthNumeric      1.000000    -0.166129    0.018573      0.951788
# MonthFactor      -0.166129     1.000000    0.023861     -0.284251
# RogueSales        0.018573     0.023861    1.000000     -0.027966
# Unemployment      0.951788    -0.284251   -0.027966      1.000000
# RogueQueries      0.776689    -0.281817    0.010250      0.834824
# CPIAll           -0.520535     0.063876    0.005178     -0.606273
# CPIEnergy         0.985993    -0.288663   -0.055626      0.955366
#
#               RogueQueries    CPIAll  CPIEnergy
# MonthNumeric      0.776689 -0.520535   0.985993
# MonthFactor      -0.281817  0.063876  -0.288663
# RogueSales        0.010250  0.005178  -0.055626
# Unemployment      0.834824 -0.606273   0.955366
# RogueQueries      1.000000 -0.708006   0.806593
# CPIAll           -0.708006  1.000000  -0.519502
# CPIEnergy         0.806593 -0.519502   1.000000
